# %% [markdown]
# # Formatting Data
# Use this file to format cleaned data into a rolling initial state that can be used

# %%
import pandas as pd

# Load data
operations = pd.read_csv('../../Data/AnalysisData/operations_cleaned_20250301.csv')

operations.head()
# Out:
#                   time operation   flight ac_type  runway
# 0  2025-03-01 00:00:38   landing  SWA4157    B38M    27.0
# 1  2025-03-01 00:02:05   takeoff  SKW3378    E75L    27.0
# 2  2025-03-01 00:04:27   landing   BAW82P    A35K    27.0
# 3  2025-03-01 00:08:37   landing  SWA3338    B737    27.0
# 4  2025-03-01 00:09:33   takeoff   EJA838    C700    27.0

# %%
# Convert time to datetime format
operations['time'] = pd.to_datetime(operations['time'], format='%Y-%m-%d %H:%M:%S', errors='coerce')

# Convert runway to integer, keeping NaN as NaN
operations['runway'] = pd.to_numeric(operations['runway'], errors='coerce').astype('Int64')

operations['flight'] = operations['flight'].astype(str)

seen = {}
for idx, op in operations.iterrows():
    if op['flight'] not in seen.keys():
        seen[op['flight']] = 1
    else:
        operations.loc[idx, 'flight'] = f"{op['flight']}_{seen[op['flight']]}"
        seen[op['flight']] += 1

operations.head()
# Out:
#                  time operation   flight ac_type  runway
# 0 2025-03-01 00:00:38   landing  SWA4157    B38M      27
# 1 2025-03-01 00:02:05   takeoff  SKW3378    E75L      27
# 2 2025-03-01 00:04:27   landing   BAW82P    A35K      27
# 3 2025-03-01 00:08:37   landing  SWA3338    B737      27
# 4 2025-03-01 00:09:33   takeoff   EJA838    C700      27

# %%
# gather rolling initial state for takeoff operations
rolling_initial_state = []
for i in range(len(operations)):
    if operations['operation'][i] == 'takeoff':
        runway_val = operations['runway'].iloc[i]
        if pd.isna(runway_val):
            # handle missing value
            raise ValueError(f"Missing runway value at index {i}")
        elif runway_val == 9:
            time_val = operations['time'][i]
            if pd.notnull(time_val):
                seconds_of_day = time_val.hour * 3600 + time_val.minute * 60 + time_val.second
            else:
                raise ValueError(f"Invalid time value at index {i}: {time_val}")
            rolling_initial_state.append({
                'callsign': operations['flight'][i],
                'runway': 9,
                'lat': 0.0,
                'lon': 0.0,
                'alt': 0.0,
                'v_z': 0.0,
                'gspd': 0.0,
                'hdg': 0.0,
                'model': operations['ac_type'][i],
                'time_added': seconds_of_day,
                'state': 'takeoff'
            })
        elif runway_val == 27:
            time_val = operations['time'][i]
            if pd.notnull(time_val):
                seconds_of_day = time_val.hour * 3600 + time_val.minute * 60 + time_val.second
            else:
                raise ValueError(f"Invalid time value at index {i}: {time_val}")
            rolling_initial_state.append({
                'callsign': operations['flight'][i],
                'runway': 27,
                'lat': 0.0,
                'lon': 0.0,
                'alt': 0.0,
                'v_z': 0.0,
                'gspd': 0.0,
                'hdg': 0.0,
                'model': operations['ac_type'][i],
                'time_added': seconds_of_day,
                'state': 'takeoff'
            })
        else:
            # handle unexpected value
            raise ValueError(f"Unexpected runway value at index {i}: {runway_val}")

print(rolling_initial_state[:5])  # Display the first 5 entries for verification
# Out:
# [{'callsign': 'SKW3378', 'runway': 27, 'lat': 0.0, 'lon': 0.0, 'alt': 0.0, 'v_z': 0.0, 'gspd': 0.0, 'hdg': 0.0, 'model': 'E75L', 'time_added': 125, 'state': 'takeoff'}, {'callsign': 'EJA838', 'runway': 27, 'lat': 0.0, 'lon': 0.0, 'alt': 0.0, 'v_z': 0.0, 'gspd': 0.0, 'hdg': 0.0, 'model': 'C700', 'time_added': 573, 'state': 'takeoff'}, {'callsign': 'UAL2117', 'runway': 27, 'lat': 0.0, 'lon': 0.0, 'alt': 0.0, 'v_z': 0.0, 'gspd': 0.0, 'hdg': 0.0, 'model': 'B738', 'time_added': 768, 'state': 'takeoff'}, {'callsign': 'SWA4363', 'runway': 27, 'lat': 0.0, 'lon': 0.0, 'alt': 0.0, 'v_z': 0.0, 'gspd': 0.0, 'hdg': 0.0, 'model': 'B737', 'time_added': 817, 'state': 'takeoff'}, {'callsign': 'SKW3473', 'runway': 27, 'lat': 0.0, 'lon': 0.0, 'alt': 0.0, 'v_z': 0.0, 'gspd': 0.0, 'hdg': 0.0, 'model': 'E75L', 'time_added': 907, 'state': 'takeoff'}]

# %%
print(rolling_initial_state[-1])  # Display last state; should be a takeoff
# Out:
# {'callsign': 'SWA4850_1', 'runway': 27, 'lat': 0.0, 'lon': 0.0, 'alt': 0.0, 'v_z': 0.0, 'gspd': 0.0, 'hdg': 0.0, 'model': 'B737', 'time_added': 86102, 'state': 'takeoff'}

# %%
# Add landing planes to rolling initial state

aircraft = pd.read_csv('../../Data/AnalysisData/aircraft_cleaned_20250301.csv')

aircraft.head()
# Out:
#              timestamp   flight     t     gs   track  baro_rate        lat  \
# 0  2025-03-01 00:00:00  ACA1013  A321    0.0  314.00        0.0  32.733467
# 1  2025-03-01 00:00:00  SWA4157  B38M  144.0  286.55     -832.0  32.729324
# 2  2025-03-01 00:00:00  SKW3378  E75L    0.0     NaN        NaN  32.729517
# 3  2025-03-01 00:00:00   EJA838  C700    0.0   14.00        0.0  32.733450
# 4  2025-03-01 00:00:00  SWA3095  B737    0.0     NaN        NaN  32.733112
#
#           lon  alt
# 0 -117.206653    0
# 1 -117.172101  158
# 2 -117.176939    0
# 3 -117.178396    0
# 4 -117.195735    0

# %%
# here, manually remove any entries that you don't want for the initial state

aircraft = aircraft[aircraft['flight'] != 'SWA4157']
aircraft = aircraft[aircraft['flight'] != 'SWA2605']

aircraft.head()
# Out:
#              timestamp   flight     t   gs  track  baro_rate        lat  \
# 0  2025-03-01 00:00:00  ACA1013  A321  0.0  314.0        0.0  32.733467
# 2  2025-03-01 00:00:00  SKW3378  E75L  0.0    NaN        NaN  32.729517
# 3  2025-03-01 00:00:00   EJA838  C700  0.0   14.0        0.0  32.733450
# 4  2025-03-01 00:00:00  SWA3095  B737  0.0    NaN        NaN  32.733112
# 5  2025-03-01 00:00:00  SWA3523  B737  0.0    NaN        NaN  32.732706
#
#           lon  alt
# 0 -117.206653    0
# 2 -117.176939    0
# 3 -117.178396    0
# 4 -117.195735    0
# 5 -117.196978    0

# %%
# convert time to datetime format
aircraft['timestamp'] = pd.to_datetime(aircraft['timestamp'], format='%Y-%m-%d %H:%M:%S', errors='coerce')

# Convert ground speed to float, track to float, baro rate to float, lat to float, lon to float, alt to float
aircraft['flight'] = aircraft['flight'].astype(str)
aircraft['gs'] = pd.to_numeric(aircraft['gs'], errors='coerce').apply(float)
aircraft['track'] = pd.to_numeric(aircraft['track'], errors='coerce').apply(float)
aircraft['baro_rate'] = pd.to_numeric(aircraft['baro_rate'], errors='coerce').apply(float)
aircraft['lat'] = pd.to_numeric(aircraft['lat'], errors='coerce').apply(float)
aircraft['lon'] = pd.to_numeric(aircraft['lon'], errors='coerce').apply(float)
aircraft['alt'] = pd.to_numeric(aircraft['alt'], errors='coerce').apply(float)

aircraft.head()
# Out:
#    timestamp   flight     t   gs  track  baro_rate        lat         lon  alt
# 0 2025-03-01  ACA1013  A321  0.0  314.0        0.0  32.733467 -117.206653  0.0
# 2 2025-03-01  SKW3378  E75L  0.0    NaN        NaN  32.729517 -117.176939  0.0
# 3 2025-03-01   EJA838  C700  0.0   14.0        0.0  32.733450 -117.178396  0.0
# 4 2025-03-01  SWA3095  B737  0.0    NaN        NaN  32.733112 -117.195735  0.0
# 5 2025-03-01  SWA3523  B737  0.0    NaN        NaN  32.732706 -117.196978  0.0

# %%
# Add landing states to rolling initial state
seen = set()
for idx, op in operations.iterrows():
    if op['operation'] == 'landing':
        callsign = str(op['flight'])
        if callsign in seen or pd.isna(callsign):
            continue
        # Extract base callsign (before any _N suffix)
        base_callsign = callsign.split('_')[0]
        op_time = op['time']
        # Find aircraft rows with base callsign, timestamp within 10 minutes, and heading within ±10 of 286
        ac_rows = aircraft[(aircraft['flight'] == base_callsign) &
                           (aircraft['timestamp'].notna()) &
                           (abs((aircraft['timestamp'] - op_time).dt.total_seconds()) <= 600) &
                           (aircraft['track'].notna()) &
                           (abs(aircraft['track'] - 286) <= 10)]
        if ac_rows.empty:
            print(f"No aircraft data found for {callsign} (base {base_callsign}) within 10 min of {op_time} and heading near 286")
            continue
        ac_row = ac_rows.iloc[0]
        state = {
            'callsign': callsign,
            'lat': float(ac_row['lat']) if not pd.isna(ac_row['lat']) else None,
            'lon': float(ac_row['lon']) if not pd.isna(ac_row['lon']) else None,
            'alt': (float(ac_row['alt']) * 0.3048) if not pd.isna(ac_row['alt']) else None, # FEET TO METERS
            'v_z': 0.0,
            'gspd': (float(ac_row['gs']) / 1.94384) if not pd.isna(ac_row['gs']) else None, # KNOTS to METERS PER SECOND
            'hdg': float(ac_row['track']) if not pd.isna(ac_row['track']) else None,
            'model': str(ac_row['t']),
            'state': 'landing',
            'time_added': (
                int(ac_row['timestamp'].hour) * 3600 +
                int(ac_row['timestamp'].minute) * 60 +
                int(ac_row['timestamp'].second)
            ) if not pd.isna(ac_row['timestamp']) else None,
            'runway': op['runway'] if not pd.isna(op['runway']) else None
        }
        rolling_initial_state.append(state)
        seen.add(callsign)
        print(f"Added landing state for {callsign} (base {base_callsign}) at {ac_row['timestamp']} with runway {state['runway']}")

print(rolling_initial_state[-1])  # Display last state; should be a landing
# Out:
# No aircraft data found for SWA4157 (base SWA4157) within 10 min of 2025-03-01 00:00:38 and heading near 286
# Added landing state for BAW82P (base BAW82P) at 2025-03-01 00:00:15 with runway 27
# Added landing state for SWA3338 (base SWA3338) at 2025-03-01 00:04:40 with runway 27
# Added landing state for UAL222 (base UAL222) at 2025-03-01 00:07:05 with runway 27
# Added landing state for SKW3346 (base SKW3346) at 2025-03-01 00:14:35 with runway 27
# Added landing state for SKW3496 (base SKW3496) at 2025-03-01 00:16:30 with runway 27
# Added landing state for ASA1454 (base ASA1454) at 2025-03-01 00:18:35 with runway 27
# Added landing state for TSU7122 (base TSU7122) at 2025-03-01 00:22:50 with runway 27
# Added landing state for SKW3439 (base SKW3439) at 2025-03-01 00:29:15 with runway 27
# Added landing state for SWA6169 (base SWA6169) at 2025-03-01 00:37:35 with runway 27
# Added landing state for SKW4087 (base SKW4087) at 2025-03-01 00:43:35 with runway 27
# Added landing state for SWA3564 (base SWA3564) at 2025-03-01 00:45:35 with runway 27
# Added landing state for EDG92 (base EDG92) at 2025-03-01 00:54:50 with runway 27
# Added landing state for SKW3829 (base SKW3829) at 2025-03-01 00:57:30 with runway 27
# Added landing state for SWA1444 (base SWA1444) at 2025-03-01 00:59:15 with runway 27
# Added landing state for ASA1204 (base ASA1204) at 2025-03-01 01:05:00 with runway 27
# Added landing state for UPS5636 (base UPS5636) at 2025-03-01 01:07:05 with runway 27
# Added landing state for SWA2225 (base SWA2225) at 2025-03-01 01:10:10 with runway 27
# Added landing state for UAL1281 (base UAL1281) at 2025-03-01 01:12:10 with runway 27
# Added landing state for SWA928 (base SWA928) at 2025-03-01 01:15:15 with runway 27
# Added landing state for SWA1883 (base SWA1883) at 2025-03-01 01:17:45 with runway 27
# Added landing state for JTL750 (base JTL750) at 2025-03-01 01:26:30 with runway 27
# Added landing state for SKW3482 (base SKW3482) at 2025-03-01 01:30:35 with runway 27
# Added landing state for EJA373 (base EJA373) at 2025-03-01 01:32:25 with runway 27
# Added landing state for AAL1890 (base AAL1890) at 2025-03-01 01:38:35 with runway 27
# Added landing state for ASA474 (base ASA474) at 2025-03-01 01:41:30 with runway 27
# Added landing state for QXE2022 (base QXE2022) at 2025-03-01 01:44:10 with runway 27
# Added landing state for SWA1915 (base SWA1915) at 2025-03-01 01:46:15 with runway 27
# Added landing state for UAL1057 (base UAL1057) at 2025-03-01 01:51:05 with runway 27
# Added landing state for PCM7685 (base PCM7685) at 2025-03-01 01:59:05 with runway None
# Added landing state for DAL712 (base DAL712) at 2025-03-01 02:03:30 with runway 27
# Added landing state for SWA3642 (base SWA3642) at 2025-03-01 02:08:50 with runway 27
# Added landing state for DAL369 (base DAL369) at 2025-03-01 02:10:15 with runway 27
# Added landing state for SWA4368 (base SWA4368) at 2025-03-01 02:12:20 with runway 27
# Added landing state for DAL2613 (base DAL2613) at 2025-03-01 02:14:20 with runway 27
# Added landing state for AAL1191 (base AAL1191) at 2025-03-01 02:15:20 with runway 27
# Added landing state for SWA4331 (base SWA4331) at 2025-03-01 02:17:10 with runway 27
# Added landing state for JBU19 (base JBU19) at 2025-03-01 02:19:15 with runway 27
# Added landing state for ASA397 (base ASA397) at 2025-03-01 02:21:00 with runway 27
# Added landing state for SWA2101 (base SWA2101) at 2025-03-01 02:23:25 with runway 27
# Added landing state for AAL621 (base AAL621) at 2025-03-01 02:29:55 with runway 27
# Added landing state for SWA4853 (base SWA4853) at 2025-03-01 02:32:00 with runway 27
# Added landing state for NKS296 (base NKS296) at 2025-03-01 02:36:00 with runway 27
# Added landing state for SWA1706 (base SWA1706) at 2025-03-01 02:38:05 with runway 27
# Added landing state for UAL2184 (base UAL2184) at 2025-03-01 02:45:40 with runway 27
# Added landing state for QXE2175 (base QXE2175) at 2025-03-01 02:48:05 with runway 27
# Added landing state for AAL1543 (base AAL1543) at 2025-03-01 02:51:20 with runway 27
# Added landing state for ASA1142 (base ASA1142) at 2025-03-01 02:57:10 with runway 27
# Added landing state for SWA4355 (base SWA4355) at 2025-03-01 02:58:05 with runway 27
# Added landing state for EJA793 (base EJA793) at 2025-03-01 03:00:20 with runway 27
# Added landing state for AAL2680 (base AAL2680) at 2025-03-01 03:07:05 with runway 27
# Added landing state for SWA3823 (base SWA3823) at 2025-03-01 03:10:20 with runway 27
# Added landing state for FFT1465 (base FFT1465) at 2025-03-01 03:12:30 with runway 27
# Added landing state for SWA3718 (base SWA3718) at 2025-03-01 03:19:15 with runway 27
# Added landing state for SWA4062 (base SWA4062) at 2025-03-01 03:22:45 with runway 27
# Added landing state for SWA2085 (base SWA2085) at 2025-03-01 03:23:50 with runway 27
# Added landing state for ASA389 (base ASA389) at 2025-03-01 03:26:50 with runway 27
# Added landing state for SWA3226 (base SWA3226) at 2025-03-01 03:28:30 with runway 27
# Added landing state for ASA806 (base ASA806) at 2025-03-01 03:32:05 with runway 27
# Added landing state for ASA894 (base ASA894) at 2025-03-01 03:37:05 with runway 27
# Added landing state for HAL16 (base HAL16) at 2025-03-01 03:39:45 with runway 27
# Added landing state for SWA3325 (base SWA3325) at 2025-03-01 03:40:05 with runway 27
# Added landing state for SWA312 (base SWA312) at 2025-03-01 03:41:25 with runway 27
# Added landing state for DAL709 (base DAL709) at 2025-03-01 03:42:45 with runway 27
# Added landing state for SWA2707 (base SWA2707) at 2025-03-01 03:44:20 with runway 27
# Added landing state for SWA4175 (base SWA4175) at 2025-03-01 03:45:55 with runway 27
# Added landing state for SKW5415 (base SKW5415) at 2025-03-01 03:47:15 with runway 27
# Added landing state for JBU1189 (base JBU1189) at 2025-03-01 03:48:40 with runway 27
# Added landing state for UAL1373 (base UAL1373) at 2025-03-01 03:50:20 with runway 27
# Added landing state for ASA297 (base ASA297) at 2025-03-01 03:52:05 with runway 27
# Added landing state for UAL8100 (base UAL8100) at 2025-03-01 04:00:00 with runway 27
# Added landing state for SKW3410_1 (base SKW3410) at 2025-03-01 04:01:35 with runway 27
# Added landing state for SKW3459 (base SKW3459) at 2025-03-01 04:05:35 with runway 27
# Added landing state for SWA3288 (base SWA3288) at 2025-03-01 04:10:50 with runway 27
# Added landing state for ASA25 (base ASA25) at 2025-03-01 04:12:40 with runway 27
# Added landing state for UAL1831 (base UAL1831) at 2025-03-01 04:14:40 with runway 27
# Added landing state for SKW3384 (base SKW3384) at 2025-03-01 04:16:15 with runway 27
# Added landing state for SKW3489 (base SKW3489) at 2025-03-01 04:18:25 with runway 27
# Added landing state for AAL1533 (base AAL1533) at 2025-03-01 04:19:20 with runway 27
# Added landing state for AAL1482 (base AAL1482) at 2025-03-01 04:22:05 with runway 27
# Added landing state for DAL2145 (base DAL2145) at 2025-03-01 04:24:40 with runway 27
# Added landing state for DAL1252 (base DAL1252) at 2025-03-01 04:26:45 with runway 27
# Added landing state for DAL571 (base DAL571) at 2025-03-01 04:28:50 with runway 27
# Added landing state for SWA4263 (base SWA4263) at 2025-03-01 04:30:40 with runway 27
# Added landing state for UAL540 (base UAL540) at 2025-03-01 04:32:35 with runway 27
# Added landing state for SKW3388_1 (base SKW3388) at 2025-03-01 04:34:35 with runway 27
# Added landing state for DAL731 (base DAL731) at 2025-03-01 04:36:20 with runway 27
# Added landing state for ASA507 (base ASA507) at 2025-03-01 04:37:50 with runway 27
# Added landing state for SWA2131 (base SWA2131) at 2025-03-01 04:42:15 with runway 27
# Added landing state for SWA4576 (base SWA4576) at 2025-03-01 04:46:30 with runway 27
# Added landing state for SWA1456 (base SWA1456) at 2025-03-01 04:47:45 with runway 27
# Added landing state for SKW3305_1 (base SKW3305) at 2025-03-01 04:49:35 with runway 27
# Added landing state for AAL1243 (base AAL1243) at 2025-03-01 04:51:40 with runway 27
# Added landing state for ASA1098 (base ASA1098) at 2025-03-01 04:54:10 with runway 27
# Added landing state for QXE2063 (base QXE2063) at 2025-03-01 04:56:55 with runway 27
# Added landing state for UAL2633 (base UAL2633) at 2025-03-01 04:59:10 with runway 27
# Added landing state for N500XX (base N500XX) at 2025-03-01 05:02:50 with runway 27
# Added landing state for QXE2431 (base QXE2431) at 2025-03-01 05:05:40 with runway 27
# Added landing state for ASA1122 (base ASA1122) at 2025-03-01 05:08:05 with runway 27
# Added landing state for SWA377 (base SWA377) at 2025-03-01 05:09:10 with runway 27
# Added landing state for SKW3378_1 (base SKW3378) at 2025-03-01 05:11:50 with runway 27
# Added landing state for UAL2674 (base UAL2674) at 2025-03-01 05:15:15 with runway 27
# Added landing state for SWA3036 (base SWA3036) at 2025-03-01 05:17:30 with runway 27
# Added landing state for SWA541 (base SWA541) at 2025-03-01 05:19:35 with runway 27
# Added landing state for SWA1669 (base SWA1669) at 2025-03-01 05:28:55 with runway 27
# Added landing state for AAL559 (base AAL559) at 2025-03-01 05:38:45 with runway 27
# Added landing state for SWA518 (base SWA518) at 2025-03-01 05:41:45 with runway 27
# Added landing state for SWA4619 (base SWA4619) at 2025-03-01 05:52:30 with runway 27
# Added landing state for UAL2154 (base UAL2154) at 2025-03-01 05:56:10 with runway 27
# Added landing state for DAL700 (base DAL700) at 2025-03-01 05:58:00 with runway 27
# Added landing state for AAL2360 (base AAL2360) at 2025-03-01 06:00:00 with runway 27
# Added landing state for DAL2672 (base DAL2672) at 2025-03-01 06:02:25 with runway 27
# Added landing state for AAL1798 (base AAL1798) at 2025-03-01 06:03:50 with runway 27
# Added landing state for SWA3976 (base SWA3976) at 2025-03-01 06:07:20 with runway 27
# Added landing state for AAL2578 (base AAL2578) at 2025-03-01 06:15:30 with runway 27
# Added landing state for UAL486 (base UAL486) at 2025-03-01 06:19:35 with runway 27
# Added landing state for SWA4111 (base SWA4111) at 2025-03-01 06:21:45 with runway 27
# Added landing state for HAL58 (base HAL58) at 2025-03-01 06:26:30 with runway 27
# Added landing state for NKS191 (base NKS191) at 2025-03-01 06:29:50 with runway 27
# Added landing state for SKW3746 (base SKW3746) at 2025-03-01 06:33:10 with runway 27
# Added landing state for SWA4489 (base SWA4489) at 2025-03-01 06:38:00 with runway 27
# Added landing state for SWA1328 (base SWA1328) at 2025-03-01 06:39:45 with runway 27
# Added landing state for DAL896 (base DAL896) at 2025-03-01 06:41:40 with runway 27
# Added landing state for N3TS (base N3TS) at 2025-03-01 06:43:45 with runway 27
# Added landing state for SWA2380 (base SWA2380) at 2025-03-01 06:45:15 with runway 27
# Added landing state for SWA1473 (base SWA1473) at 2025-03-01 06:51:35 with runway 27
# Added landing state for SWA4316 (base SWA4316) at 2025-03-01 06:55:35 with runway 27
# Added landing state for SKW836E (base SKW836E) at 2025-03-01 06:58:00 with runway 27
# Added landing state for SWA1017 (base SWA1017) at 2025-03-01 06:59:20 with runway 27
# Added landing state for ASA1131 (base ASA1131) at 2025-03-01 07:01:25 with runway 27
# Added landing state for SWA3824 (base SWA3824) at 2025-03-01 07:03:10 with runway 27
# Added landing state for AAL2986 (base AAL2986) at 2025-03-01 07:15:55 with runway 27
# Added landing state for DAL1202 (base DAL1202) at 2025-03-01 07:18:30 with runway 27
# Added landing state for AAL2568 (base AAL2568) at 2025-03-01 07:30:30 with runway 27
# Added landing state for DAL685 (base DAL685) at 2025-03-01 07:34:15 with runway 27
# Added landing state for SKW5612 (base SKW5612) at 2025-03-01 07:42:55 with runway 27
# Added landing state for ASA1162 (base ASA1162) at 2025-03-01 07:51:10 with runway 27
# Added landing state for UAL548 (base UAL548) at 2025-03-01 07:53:30 with runway 27
# Added landing state for FFT4989 (base FFT4989) at 2025-03-01 08:16:00 with runway 27
# Added landing state for ASA1156 (base ASA1156) at 2025-03-01 08:22:35 with runway 27
# Added landing state for FDX1889 (base FDX1889) at 2025-03-01 12:43:15 with runway 27
# Added landing state for UPS922 (base UPS922) at 2025-03-01 13:24:40 with runway 27
# Added landing state for FDX1422 (base FDX1422) at 2025-03-01 13:30:15 with runway 27
# Added landing state for ASA892 (base ASA892) at 2025-03-01 14:38:25 with runway 27
# Added landing state for SKW3415 (base SKW3415) at 2025-03-01 14:57:35 with runway 27
# Added landing state for SKW3310 (base SKW3310) at 2025-03-01 15:01:05 with runway 27
# Added landing state for SKW847Y (base SKW847Y) at 2025-03-01 15:09:40 with runway 27
# Added landing state for SKW3399 (base SKW3399) at 2025-03-01 15:11:40 with runway 27
# Added landing state for SKW3401 (base SKW3401) at 2025-03-01 15:14:10 with runway 27
# Added landing state for SKW3360 (base SKW3360) at 2025-03-01 15:22:15 with runway 27
# Added landing state for SWA5061 (base SWA5061) at 2025-03-01 15:25:15 with runway 27
# Added landing state for SKW3372 (base SKW3372) at 2025-03-01 15:29:55 with runway 27
# Added landing state for ASA195 (base ASA195) at 2025-03-01 15:34:35 with runway 27
# Added landing state for SWA4379 (base SWA4379) at 2025-03-01 15:36:15 with runway 27
# Added landing state for SWA4010 (base SWA4010) at 2025-03-01 15:38:30 with runway 27
# Added landing state for SWA121 (base SWA121) at 2025-03-01 15:58:20 with runway 27
# Added landing state for SWA1482 (base SWA1482) at 2025-03-01 16:00:10 with runway 27
# Added landing state for SKW3337 (base SKW3337) at 2025-03-01 16:02:15 with runway 27
# Added landing state for FFT3167 (base FFT3167) at 2025-03-01 16:03:55 with runway 27
# Added landing state for SWA3015 (base SWA3015) at 2025-03-01 16:05:45 with runway 27
# Added landing state for SWA2476 (base SWA2476) at 2025-03-01 16:17:15 with runway 27
# Added landing state for ASA912 (base ASA912) at 2025-03-01 16:20:05 with runway 27
# Added landing state for SKW3785 (base SKW3785) at 2025-03-01 16:23:35 with runway 27
# Added landing state for SWA1794 (base SWA1794) at 2025-03-01 16:29:50 with runway 27
# Added landing state for UAL623 (base UAL623) at 2025-03-01 16:32:25 with runway 27
# Added landing state for NKS294 (base NKS294) at 2025-03-01 16:35:00 with runway 27
# Added landing state for FFT1425 (base FFT1425) at 2025-03-01 16:39:30 with runway 27
# Added landing state for SWA909 (base SWA909) at 2025-03-01 16:41:05 with runway 27
# Added landing state for DAL1177 (base DAL1177) at 2025-03-01 16:43:10 with runway 27
# Added landing state for AAL1720 (base AAL1720) at 2025-03-01 16:45:15 with runway 27
# Added landing state for UAL2309 (base UAL2309) at 2025-03-01 16:48:50 with runway 27
# Added landing state for JBU619 (base JBU619) at 2025-03-01 16:52:05 with runway 27
# Added landing state for SWA3332 (base SWA3332) at 2025-03-01 16:54:15 with runway 27
# Added landing state for JBU289 (base JBU289) at 2025-03-01 17:05:40 with runway 27
# Added landing state for XSM92 (base XSM92) at 2025-03-01 17:08:30 with runway 27
# Added landing state for SKW4643 (base SKW4643) at 2025-03-01 17:18:35 with runway 27
# Added landing state for QXE2154 (base QXE2154) at 2025-03-01 17:25:10 with runway 27
# Added landing state for UAL1626 (base UAL1626) at 2025-03-01 17:26:40 with runway 27
# Added landing state for ASA1021 (base ASA1021) at 2025-03-01 17:28:15 with runway 27
# Added landing state for SKW3456 (base SKW3456) at 2025-03-01 17:32:40 with runway 27
# Added landing state for UAL2230 (base UAL2230) at 2025-03-01 17:36:35 with runway 27
# Added landing state for PCM8684_1 (base PCM8684) at 2025-03-01 17:46:45 with runway 27
# Added landing state for AAL2366 (base AAL2366) at 2025-03-01 17:49:35 with runway 27
# Added landing state for SWA138 (base SWA138) at 2025-03-01 17:54:10 with runway 27
# Added landing state for ASA145 (base ASA145) at 2025-03-01 17:55:35 with runway 27
# Added landing state for DAL2508 (base DAL2508) at 2025-03-01 17:57:45 with runway 27
# Added landing state for SWA2068 (base SWA2068) at 2025-03-01 17:59:45 with runway 27
# Added landing state for EJA478 (base EJA478) at 2025-03-01 18:02:10 with runway 27
# Added landing state for SWA2093_1 (base SWA2093) at 2025-03-01 18:05:00 with runway 27
# Added landing state for SWA1245 (base SWA1245) at 2025-03-01 18:09:00 with runway 27
# Added landing state for SKW4001 (base SKW4001) at 2025-03-01 18:10:25 with runway 27
# Added landing state for N577CS (base N577CS) at 2025-03-01 18:12:30 with runway 27
# Added landing state for DAL725 (base DAL725) at 2025-03-01 18:14:50 with runway 27
# Added landing state for SWA1300 (base SWA1300) at 2025-03-01 18:16:55 with runway 27
# Added landing state for ASA1296 (base ASA1296) at 2025-03-01 18:19:00 with runway 27
# Added landing state for DAL492 (base DAL492) at 2025-03-01 18:23:55 with runway 27
# Added landing state for EJA386 (base EJA386) at 2025-03-01 18:27:35 with runway 27
# Added landing state for SWA2807 (base SWA2807) at 2025-03-01 18:33:05 with runway 27
# Added landing state for FFT2083 (base FFT2083) at 2025-03-01 18:35:50 with runway 27
# Added landing state for UAL2491 (base UAL2491) at 2025-03-01 18:40:20 with runway 27
# Added landing state for JZA764 (base JZA764) at 2025-03-01 18:42:40 with runway 27
# Added landing state for AAL1149 (base AAL1149) at 2025-03-01 18:44:05 with runway 27
# Added landing state for ASA1258 (base ASA1258) at 2025-03-01 18:46:35 with runway 27
# Added landing state for SWA1471 (base SWA1471) at 2025-03-01 18:50:45 with runway 27
# Added landing state for UAL1930 (base UAL1930) at 2025-03-01 18:55:05 with runway 27
# Added landing state for UAL660 (base UAL660) at 2025-03-01 18:59:40 with runway 27
# Added landing state for LXJ418 (base LXJ418) at 2025-03-01 19:01:45 with runway 27
# Added landing state for SWA492 (base SWA492) at 2025-03-01 19:03:20 with runway 27
# Added landing state for SWA3642_2 (base SWA3642) at 2025-03-01 19:06:10 with runway 27
# Added landing state for FFT4927 (base FFT4927) at 2025-03-01 19:07:35 with runway 27
# Added landing state for SWA4910 (base SWA4910) at 2025-03-01 19:12:15 with runway 27
# Added landing state for DAL683 (base DAL683) at 2025-03-01 19:18:40 with runway 27
# Added landing state for N887WT (base N887WT) at 2025-03-01 19:21:45 with runway 27
# Added landing state for N274WA (base N274WA) at 2025-03-01 19:24:05 with runway 27
# Added landing state for N60XG (base N60XG) at 2025-03-01 19:25:40 with runway 27
# Added landing state for AAL1621 (base AAL1621) at 2025-03-01 19:27:30 with runway 27
# Added landing state for SIS61 (base SIS61) at 2025-03-01 19:29:55 with runway 27
# Added landing state for SWA1543 (base SWA1543) at 2025-03-01 19:31:45 with runway 27
# Added landing state for SWA866 (base SWA866) at 2025-03-01 19:37:50 with runway 27
# Added landing state for N851FW (base N851FW) at 2025-03-01 19:43:45 with runway 27
# Added landing state for SWA2084 (base SWA2084) at 2025-03-01 19:44:10 with runway 27
# Added landing state for AAL1302 (base AAL1302) at 2025-03-01 19:47:25 with runway 27
# Added landing state for SKW3368 (base SKW3368) at 2025-03-01 19:49:25 with runway 27
# Added landing state for UAL1826 (base UAL1826) at 2025-03-01 19:53:15 with runway 27
# Added landing state for DAL1179 (base DAL1179) at 2025-03-01 19:55:20 with runway 27
# Added landing state for ACA1093 (base ACA1093) at 2025-03-01 19:57:25 with runway 27
# Added landing state for WJA1564 (base WJA1564) at 2025-03-01 19:59:35 with runway 27
# Added landing state for SWA1211 (base SWA1211) at 2025-03-01 20:01:15 with runway 27
# Added landing state for SWA2152 (base SWA2152) at 2025-03-01 20:03:10 with runway 27
# Added landing state for DAL2533 (base DAL2533) at 2025-03-01 20:04:50 with runway 27
# Added landing state for AAL2131 (base AAL2131) at 2025-03-01 20:08:45 with runway 27
# Added landing state for SKW3359 (base SKW3359) at 2025-03-01 20:10:20 with runway 27
# Added landing state for ASA1108 (base ASA1108) at 2025-03-01 20:13:05 with runway 27
# Added landing state for VJA308 (base VJA308) at 2025-03-01 20:14:55 with runway 27
# Added landing state for BBQ8275 (base BBQ8275) at 2025-03-01 20:17:40 with runway 27
# Added landing state for AAL1955 (base AAL1955) at 2025-03-01 20:25:40 with runway 27
# Added landing state for ASA884 (base ASA884) at 2025-03-01 20:33:15 with runway 27
# Added landing state for SKW3967 (base SKW3967) at 2025-03-01 20:35:15 with runway 27
# Added landing state for LXJ512 (base LXJ512) at 2025-03-01 20:38:30 with runway 27
# Added landing state for SWA2272 (base SWA2272) at 2025-03-01 20:45:50 with runway 27
# Added landing state for UAL366 (base UAL366) at 2025-03-01 20:47:55 with runway 27
# Added landing state for DAL896_1 (base DAL896) at 2025-03-01 20:49:55 with runway 27
# Added landing state for SWA2038 (base SWA2038) at 2025-03-01 20:51:55 with runway 27
# Added landing state for SKW3488_1 (base SKW3488) at 2025-03-01 20:57:45 with runway 27
# Added landing state for ASA1425 (base ASA1425) at 2025-03-01 20:59:35 with runway 27
# Added landing state for EJA319 (base EJA319) at 2025-03-01 21:01:40 with runway 27
# Added landing state for DAL2125 (base DAL2125) at 2025-03-01 21:04:35 with runway 27
# Added landing state for SWA208 (base SWA208) at 2025-03-01 21:09:40 with runway 27
# Added landing state for SWA1416 (base SWA1416) at 2025-03-01 21:12:15 with runway 27
# Added landing state for SWA2634_1 (base SWA2634) at 2025-03-01 21:19:20 with runway 27
# Added landing state for LXJ554 (base LXJ554) at 2025-03-01 21:22:25 with runway 27
# Added landing state for FFT1469 (base FFT1469) at 2025-03-01 21:23:50 with runway 27
# Added landing state for AAL466 (base AAL466) at 2025-03-01 21:25:50 with runway 27
# Added landing state for SWA1087 (base SWA1087) at 2025-03-01 21:31:10 with runway 27
# Added landing state for NKS1641 (base NKS1641) at 2025-03-01 21:37:10 with runway 27
# Added landing state for SKW3271 (base SKW3271) at 2025-03-01 21:41:45 with runway 27
# Added landing state for SKW3467_1 (base SKW3467) at 2025-03-01 21:46:05 with runway 27
# Added landing state for SWA4982 (base SWA4982) at 2025-03-01 21:54:05 with runway 27
# Added landing state for AAL1939 (base AAL1939) at 2025-03-01 21:56:50 with runway 27
# Added landing state for N916KP (base N916KP) at 2025-03-01 22:05:40 with runway 27
# Added landing state for RKJ104 (base RKJ104) at 2025-03-01 22:09:10 with runway 27
# Added landing state for LXJ423 (base LXJ423) at 2025-03-01 22:13:55 with runway 27
# Added landing state for ASA1395 (base ASA1395) at 2025-03-01 22:21:45 with runway 27
# Added landing state for SWA1457 (base SWA1457) at 2025-03-01 22:23:15 with runway 27
# Added landing state for QXE2225 (base QXE2225) at 2025-03-01 22:38:20 with runway 27
# Added landing state for N810BS (base N810BS) at 2025-03-01 22:41:20 with runway 27
# Added landing state for UAL2041 (base UAL2041) at 2025-03-01 22:43:40 with runway 27
# Added landing state for SWA4850 (base SWA4850) at 2025-03-01 22:46:10 with runway 27
# Added landing state for SWA3528 (base SWA3528) at 2025-03-01 22:48:25 with runway 27
# Added landing state for N513MG (base N513MG) at 2025-03-01 22:59:45 with runway 27
# Added landing state for SKW843H (base SKW843H) at 2025-03-01 23:07:40 with runway 27
# Added landing state for AAL1951_1 (base AAL1951) at 2025-03-01 23:11:15 with runway 27
# Added landing state for DAL2572 (base DAL2572) at 2025-03-01 23:13:20 with runway 27
# Added landing state for SWA3302 (base SWA3302) at 2025-03-01 23:15:35 with runway 27
# Added landing state for N273TM (base N273TM) at 2025-03-01 23:17:30 with runway 27
# Added landing state for DLH5Y (base DLH5Y) at 2025-03-01 23:19:20 with runway 27
# Added landing state for SKW827C (base SKW827C) at 2025-03-01 23:22:10 with runway 27
# Added landing state for AAL2361_1 (base AAL2361) at 2025-03-01 23:31:10 with runway 27
# Added landing state for SWA1425_1 (base SWA1425) at 2025-03-01 23:34:40 with runway 27
# Added landing state for SKW3320_1 (base SKW3320) at 2025-03-01 23:40:20 with runway 27
# Added landing state for UAL2029 (base UAL2029) at 2025-03-01 23:42:25 with runway 27
# Added landing state for SWA927 (base SWA927) at 2025-03-01 23:44:45 with runway 27
# Added landing state for UAL2683 (base UAL2683) at 2025-03-01 23:46:15 with runway 27
# Added landing state for LXJ598 (base LXJ598) at 2025-03-01 23:47:55 with runway 27
# Added landing state for DAL1210 (base DAL1210) at 2025-03-01 23:49:25 with runway 27
# Added landing state for BAW82P_1 (base BAW82P) at 2025-03-01 23:51:40 with runway 27
# Added landing state for QXE2379 (base QXE2379) at 2025-03-01 23:54:05 with runway 27
# {'callsign': 'QXE2379', 'lat': 32.686002, 'lon': -116.992231, 'alt': 1046.3784, 'v_z': 0.0, 'gspd': 92.96032595275331, 'hdg': 283.11, 'model': 'E75L', 'state': 'landing', 'time_added': 86045, 'runway': 27}

# %%
# sort by time_added
rolling_initial_state.sort(key=lambda x: x['time_added'])

# %%
# split into pieces of 10
chunk_size = 10
chunks = [rolling_initial_state[i:i + chunk_size] for i in range(0, len(rolling_initial_state), chunk_size)]

# %%
# In each chunk, start times at 0
for i in range(len(chunks)):
    for state in chunks[i]:
        state['time_added'] -= chunks[i][0]['time_added']

# %%
# export the rolling initial state dictionary to a python file
with open("../rolling_initial_state_20250301.py", "w") as f:
    for i in range(len(chunks)):
        rolling_initial_state = chunks[i]
        f.write(f"rolling_initial_state_{i:02d} = {rolling_initial_state}\n")
