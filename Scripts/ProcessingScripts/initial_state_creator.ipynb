# %% [markdown]
# # Formatting Data
# Use this file to format cleaned data into a rolling initial state that can be used

# %%
import pandas as pd

# Load data
operations = pd.read_csv('../../Data/AnalysisData/operations_cleaned_20250501.csv')

operations.head()
# Out:
#                   time operation   flight ac_type  runway
# 0  2025-05-01 00:00:08   takeoff  AAL1951    A320    27.0
# 1  2025-05-01 00:00:39   takeoff   N950DM    GA6C    27.0
# 2  2025-05-01 00:01:46   takeoff  UAL2486    B738    27.0
# 3  2025-05-01 00:03:05   takeoff  SWA1356    B38M    27.0
# 4  2025-05-01 00:06:20   landing  UPS2636    B763    27.0

# %%
# Convert time to datetime format
operations['time'] = pd.to_datetime(operations['time'], format='%Y-%m-%d %H:%M:%S', errors='coerce')

# Convert runway to integer, keeping NaN as NaN
operations['runway'] = pd.to_numeric(operations['runway'], errors='coerce').astype('Int64')

operations['flight'] = operations['flight'].astype(str)

seen = {}
for idx, op in operations.iterrows():
    if op['flight'] not in seen.keys():
        seen[op['flight']] = 1
    else:
        operations.loc[idx, 'flight'] = f"{op['flight']}_{seen[op['flight']]}"
        seen[op['flight']] += 1

operations.head()
# Out:
#                  time operation   flight ac_type  runway
# 0 2025-05-01 00:00:08   takeoff  AAL1951    A320      27
# 1 2025-05-01 00:00:39   takeoff   N950DM    GA6C      27
# 2 2025-05-01 00:01:46   takeoff  UAL2486    B738      27
# 3 2025-05-01 00:03:05   takeoff  SWA1356    B38M      27
# 4 2025-05-01 00:06:20   landing  UPS2636    B763      27

# %%
# gather rolling initial state for takeoff operations
rolling_initial_state = []
for i in range(len(operations)):
    if operations['operation'][i] == 'takeoff':
        runway_val = operations['runway'].iloc[i]
        if pd.isna(runway_val):
            # handle missing value
            raise ValueError(f"Missing runway value at index {i}")
        elif runway_val == 9:
            pass # temporarily disabling runway 9 processing
            time_val = operations['time'][i]
            if pd.notnull(time_val):
                seconds_of_day = time_val.hour * 3600 + time_val.minute * 60 + time_val.second
            else:
                raise ValueError(f"Invalid time value at index {i}: {time_val}")
            rolling_initial_state.append({
                'callsign': operations['flight'][i],
                'runway': 9,
                'lat': 0.0,
                'lon': 0.0,
                'alt': 0.0,
                'v_z': 0.0,
                'gspd': 0.0,
                'hdg': 0.0,
                'model': operations['ac_type'][i],
                'time_added': seconds_of_day,
                'state': 'takeoff'
            })
        elif runway_val == 27:
            time_val = operations['time'][i]
            if pd.notnull(time_val):
                seconds_of_day = time_val.hour * 3600 + time_val.minute * 60 + time_val.second
            else:
                raise ValueError(f"Invalid time value at index {i}: {time_val}")
            rolling_initial_state.append({
                'callsign': operations['flight'][i],
                'runway': 27,
                'lat': 0.0,
                'lon': 0.0,
                'alt': 0.0,
                'v_z': 0.0,
                'gspd': 0.0,
                'hdg': 0.0,
                'model': operations['ac_type'][i],
                'time_added': seconds_of_day,
                'state': 'takeoff'
            })
        else:
            # handle unexpected value
            raise ValueError(f"Unexpected runway value at index {i}: {runway_val}")

print(rolling_initial_state[:5])  # Display the first 5 entries for verification
# Out:
# [{'callsign': 'AAL1951', 'runway': 27, 'lat': 0.0, 'lon': 0.0, 'alt': 0.0, 'v_z': 0.0, 'gspd': 0.0, 'hdg': 0.0, 'model': 'A320', 'time_added': 8, 'state': 'takeoff'}, {'callsign': 'N950DM', 'runway': 27, 'lat': 0.0, 'lon': 0.0, 'alt': 0.0, 'v_z': 0.0, 'gspd': 0.0, 'hdg': 0.0, 'model': 'GA6C', 'time_added': 39, 'state': 'takeoff'}, {'callsign': 'UAL2486', 'runway': 27, 'lat': 0.0, 'lon': 0.0, 'alt': 0.0, 'v_z': 0.0, 'gspd': 0.0, 'hdg': 0.0, 'model': 'B738', 'time_added': 106, 'state': 'takeoff'}, {'callsign': 'SWA1356', 'runway': 27, 'lat': 0.0, 'lon': 0.0, 'alt': 0.0, 'v_z': 0.0, 'gspd': 0.0, 'hdg': 0.0, 'model': 'B38M', 'time_added': 185, 'state': 'takeoff'}, {'callsign': 'SWA2316', 'runway': 27, 'lat': 0.0, 'lon': 0.0, 'alt': 0.0, 'v_z': 0.0, 'gspd': 0.0, 'hdg': 0.0, 'model': 'B737', 'time_added': 450, 'state': 'takeoff'}]

# %%
print(rolling_initial_state[-1])  # Display last state; should be a takeoff
# Out:
# {'callsign': 'ASA1490', 'runway': 27, 'lat': 0.0, 'lon': 0.0, 'alt': 0.0, 'v_z': 0.0, 'gspd': 0.0, 'hdg': 0.0, 'model': 'B39M', 'time_added': 85965, 'state': 'takeoff'}

# %%
# Add landing planes to rolling initial state

aircraft = pd.read_csv('../../Data/AnalysisData/aircraft_cleaned_20250501.csv')

aircraft.head()
# Out:
#              timestamp   flight     t   gs  track  baro_rate        lat  \
# 0  2025-05-01 00:00:00  AAL2361  A321  9.8    NaN        NaN  32.735208
# 1  2025-05-01 00:00:00   N950DM  GA6C  7.8    NaN        NaN  32.730192
# 2  2025-05-01 00:00:00  UAL2486  B738  0.0    NaN        NaN  32.729565
# 3  2025-05-01 00:00:00  SWA1356  B38M  1.4    NaN        NaN  32.729347
# 4  2025-05-01 00:00:00      NaN  B763  0.0    NaN        NaN  32.738210
#
#           lon  alt
# 0 -117.202317    0
# 1 -117.175453    0
# 2 -117.176770    0
# 3 -117.177525    0
# 4 -117.186314    0

# %%
# here, manually remove any entries that you don't want for the initial state

# aircraft = aircraft[aircraft['flight'] != 'SWA4157']
# aircraft = aircraft[aircraft['flight'] != 'SWA2605']

aircraft.head()
# Out:
#              timestamp   flight     t   gs  track  baro_rate        lat  \
# 0  2025-03-01 00:00:00  ACA1013  A321  0.0  314.0        0.0  32.733467
# 2  2025-03-01 00:00:00  SKW3378  E75L  0.0    NaN        NaN  32.729517
# 3  2025-03-01 00:00:00   EJA838  C700  0.0   14.0        0.0  32.733450
# 4  2025-03-01 00:00:00  SWA3095  B737  0.0    NaN        NaN  32.733112
# 5  2025-03-01 00:00:00  SWA3523  B737  0.0    NaN        NaN  32.732706
#
#           lon  alt
# 0 -117.206653    0
# 2 -117.176939    0
# 3 -117.178396    0
# 4 -117.195735    0
# 5 -117.196978    0

# %%
# convert time to datetime format
aircraft['timestamp'] = pd.to_datetime(aircraft['timestamp'], format='%Y-%m-%d %H:%M:%S', errors='coerce')

# Convert ground speed to float, track to float, baro rate to float, lat to float, lon to float, alt to float
aircraft['flight'] = aircraft['flight'].astype(str)
aircraft['gs'] = pd.to_numeric(aircraft['gs'], errors='coerce').apply(float)
aircraft['track'] = pd.to_numeric(aircraft['track'], errors='coerce').apply(float)
aircraft['baro_rate'] = pd.to_numeric(aircraft['baro_rate'], errors='coerce').apply(float)
aircraft['lat'] = pd.to_numeric(aircraft['lat'], errors='coerce').apply(float)
aircraft['lon'] = pd.to_numeric(aircraft['lon'], errors='coerce').apply(float)
aircraft['alt'] = pd.to_numeric(aircraft['alt'], errors='coerce').apply(float)

aircraft.head()
# Out:
#    timestamp   flight     t   gs  track  baro_rate        lat         lon  alt
# 0 2025-05-01  AAL2361  A321  9.8    NaN        NaN  32.735208 -117.202317  0.0
# 1 2025-05-01   N950DM  GA6C  7.8    NaN        NaN  32.730192 -117.175453  0.0
# 2 2025-05-01  UAL2486  B738  0.0    NaN        NaN  32.729565 -117.176770  0.0
# 3 2025-05-01  SWA1356  B38M  1.4    NaN        NaN  32.729347 -117.177525  0.0
# 4 2025-05-01      nan  B763  0.0    NaN        NaN  32.738210 -117.186314  0.0

# %%
# Add landing states to rolling initial state
seen = set()
for idx, op in operations.iterrows():
    if op['operation'] == 'landing':
        callsign = str(op['flight'])
        if callsign in seen or pd.isna(callsign):
            continue
        # Extract base callsign (before any _N suffix)
        base_callsign = callsign.split('_')[0]
        op_time = op['time']
        # Find aircraft rows with base callsign, timestamp within 10 minutes, and heading within ±10 of 286
        ac_rows = aircraft[(aircraft['flight'] == base_callsign) &
                           (aircraft['timestamp'].notna()) &
                           (abs((aircraft['timestamp'] - op_time).dt.total_seconds()) <= 600) &
                           (aircraft['track'].notna()) &
                           (abs(aircraft['track'] - 286) <= 20)]
        if ac_rows.empty:
            print(f"No aircraft data found for {callsign} (base {base_callsign}) within 10 min of {op_time} and heading near 286")
            continue
        ac_row = ac_rows.iloc[0]
        state = {
            'callsign': callsign,
            'lat': float(ac_row['lat']) if not pd.isna(ac_row['lat']) else None,
            'lon': float(ac_row['lon']) if not pd.isna(ac_row['lon']) else None,
            'alt': (float(ac_row['alt']) * 0.3048) if not pd.isna(ac_row['alt']) else None, # FEET TO METERS
            'v_z': 0.0,
            'gspd': (float(ac_row['gs']) / 1.94384) if not pd.isna(ac_row['gs']) else None, # KNOTS to METERS PER SECOND
            'hdg': 286.0, #float(ac_row['track']) if not pd.isna(ac_row['track']) else None,
            'model': str(ac_row['t']),
            'state': 'landing',
            'time_added': (
                int(ac_row['timestamp'].hour) * 3600 +
                int(ac_row['timestamp'].minute) * 60 +
                int(ac_row['timestamp'].second)
            ) if not pd.isna(ac_row['timestamp']) else None,
            'runway': op['runway'] if not pd.isna(op['runway']) else None
        }
        rolling_initial_state.append(state)
        seen.add(callsign)
        print(f"Added landing state for {callsign} (base {base_callsign}) at {ac_row['timestamp']} with runway {state['runway']}")

print(rolling_initial_state[-1])  # Display last state; should be a landing
# Out:
# Added landing state for UPS2636 (base UPS2636) at 2025-05-01 00:01:45 with runway 27
# Added landing state for ACA1014 (base ACA1014) at 2025-05-01 00:05:55 with runway 27
# Added landing state for SKW3607 (base SKW3607) at 2025-05-01 00:08:50 with runway 27
# Added landing state for VJA536 (base VJA536) at 2025-05-01 00:11:50 with runway 27
# Added landing state for SWA495 (base SWA495) at 2025-05-01 00:21:50 with runway 27
# Added landing state for SWA1568 (base SWA1568) at 2025-05-01 00:25:15 with runway 27
# Added landing state for SWA1397 (base SWA1397) at 2025-05-01 00:28:20 with runway 27
# Added landing state for SKW3378 (base SKW3378) at 2025-05-01 00:31:20 with runway 27
# Added landing state for SKW5415 (base SKW5415) at 2025-05-01 00:33:10 with runway 27
# Added landing state for PCM7684 (base PCM7684) at 2025-05-01 00:34:55 with runway None
# Added landing state for DAL2613 (base DAL2613) at 2025-05-01 00:39:00 with runway 27
# Added landing state for BAW82P (base BAW82P) at 2025-05-01 00:42:15 with runway 27
# Added landing state for ASA1397 (base ASA1397) at 2025-05-01 00:45:10 with runway 27
# Added landing state for SWA935 (base SWA935) at 2025-05-01 00:47:50 with runway 27
# Added landing state for EJA637 (base EJA637) at 2025-05-01 00:51:05 with runway 27
# Added landing state for SWA3105 (base SWA3105) at 2025-05-01 00:52:35 with runway 27
# Added landing state for FFT1571 (base FFT1571) at 2025-05-01 00:55:40 with runway 27
# Added landing state for EJM999 (base EJM999) at 2025-05-01 01:02:15 with runway 27
# Added landing state for UAL1434 (base UAL1434) at 2025-05-01 01:07:25 with runway 27
# Added landing state for AAL480 (base AAL480) at 2025-05-01 01:10:00 with runway 27
# Added landing state for PCM7685 (base PCM7685) at 2025-05-01 01:12:00 with runway None
# Added landing state for LXJ419 (base LXJ419) at 2025-05-01 01:14:50 with runway 27
# Added landing state for SWA673 (base SWA673) at 2025-05-01 01:16:35 with runway 27
# Added landing state for SWA1296 (base SWA1296) at 2025-05-01 01:18:30 with runway 27
# Added landing state for AAL3245 (base AAL3245) at 2025-05-01 01:20:50 with runway 27
# Added landing state for DAL1252 (base DAL1252) at 2025-05-01 01:28:25 with runway 27
# Added landing state for SKW3133 (base SKW3133) at 2025-05-01 01:30:10 with runway 27
# Added landing state for PFT103 (base PFT103) at 2025-05-01 01:31:50 with runway 27
# Added landing state for SWA1870 (base SWA1870) at 2025-05-01 01:33:25 with runway 27
# Added landing state for ASA1146 (base ASA1146) at 2025-05-01 01:36:25 with runway 27
# Added landing state for SWA2965 (base SWA2965) at 2025-05-01 01:38:00 with runway 27
# Added landing state for XBILI (base XBILI) at 2025-05-01 01:36:20 with runway 27
# Added landing state for ASA474 (base ASA474) at 2025-05-01 01:45:20 with runway 27
# Added landing state for AAL562 (base AAL562) at 2025-05-01 01:55:25 with runway 27
# Added landing state for SWA1372 (base SWA1372) at 2025-05-01 01:59:55 with runway 27
# Added landing state for JBU319 (base JBU319) at 2025-05-01 02:01:50 with runway 27
# Added landing state for UAL2331 (base UAL2331) at 2025-05-01 02:03:50 with runway 27
# Added landing state for AAL1543 (base AAL1543) at 2025-05-01 02:05:55 with runway 27
# Added landing state for SKW3489 (base SKW3489) at 2025-05-01 03:28:25 with runway 27
# Added landing state for ASA1098 (base ASA1098) at 2025-05-01 03:30:45 with runway 27
# Added landing state for SWA756 (base SWA756) at 2025-05-01 03:33:05 with runway 27
# Added landing state for NKS379 (base NKS379) at 2025-05-01 03:35:05 with runway 27
# Added landing state for AAL2056 (base AAL2056) at 2025-05-01 03:46:00 with runway 27
# Added landing state for SKW3455 (base SKW3455) at 2025-05-01 03:54:30 with runway 27
# Added landing state for HAL58 (base HAL58) at 2025-05-01 03:56:40 with runway 27
# Added landing state for SWA4173 (base SWA4173) at 2025-05-01 03:58:50 with runway 27
# Added landing state for UAL2674 (base UAL2674) at 2025-05-01 04:03:20 with runway 27
# Added landing state for SWA4586 (base SWA4586) at 2025-05-01 04:08:00 with runway 27
# Added landing state for AAL559 (base AAL559) at 2025-05-01 04:15:10 with runway 27
# Added landing state for JZA768 (base JZA768) at 2025-05-01 04:17:50 with runway 27
# Added landing state for SWA2927 (base SWA2927) at 2025-05-01 03:12:05 with runway 27
# Added landing state for SKW3384 (base SKW3384) at 2025-05-01 03:14:25 with runway 27
# Added landing state for ASA854 (base ASA854) at 2025-05-01 03:16:05 with runway 27
# Added landing state for UAL1373 (base UAL1373) at 2025-05-01 03:17:50 with runway 27
# Added landing state for UAL2633 (base UAL2633) at 2025-05-01 03:19:25 with runway 27
# Added landing state for ASA899 (base ASA899) at 2025-05-01 03:20:50 with runway 27
# Added landing state for SKW3388_1 (base SKW3388) at 2025-05-01 03:22:45 with runway 27
# Added landing state for DAL571 (base DAL571) at 2025-05-01 03:24:10 with runway 27
# Added landing state for SWA448 (base SWA448) at 2025-05-01 03:25:50 with runway 27
# Added landing state for SKW3489 (base SKW3489) at 2025-05-01 03:28:25 with runway 27
# Added landing state for ASA1098 (base ASA1098) at 2025-05-01 03:30:45 with runway 27
# Added landing state for SWA756 (base SWA756) at 2025-05-01 03:33:05 with runway 27
# Added landing state for NKS379 (base NKS379) at 2025-05-01 03:35:05 with runway 27
# Added landing state for AAL2056 (base AAL2056) at 2025-05-01 03:46:00 with runway 27
# Added landing state for SKW3455 (base SKW3455) at 2025-05-01 03:54:30 with runway 27
# Added landing state for HAL58 (base HAL58) at 2025-05-01 03:56:40 with runway 27
# Added landing state for SWA4173 (base SWA4173) at 2025-05-01 03:58:50 with runway 27
# Added landing state for UAL2674 (base UAL2674) at 2025-05-01 04:03:20 with runway 27
# Added landing state for SWA4586 (base SWA4586) at 2025-05-01 04:08:00 with runway 27
# Added landing state for AAL559 (base AAL559) at 2025-05-01 04:15:10 with runway 27
# Added landing state for JZA768 (base JZA768) at 2025-05-01 04:17:50 with runway 27
# Added landing state for SWA4236 (base SWA4236) at 2025-05-01 04:23:00 with runway 27
# Added landing state for ASA297 (base ASA297) at 2025-05-01 04:35:00 with runway 27
# Added landing state for AAL1497 (base AAL1497) at 2025-05-01 04:38:20 with runway 27
# Added landing state for HAL16 (base HAL16) at 2025-05-01 04:50:05 with runway 27
# Added landing state for DAL2672 (base DAL2672) at 2025-05-01 04:52:20 with runway 27
# Added landing state for SWA1515 (base SWA1515) at 2025-05-01 04:55:00 with runway 27
# Added landing state for SWA1328 (base SWA1328) at 2025-05-01 04:57:20 with runway 27
# Added landing state for DAL748 (base DAL748) at 2025-05-01 05:00:20 with runway 27
# Added landing state for UAL1074 (base UAL1074) at 2025-05-01 05:02:15 with runway 27
# Added landing state for SWA3888 (base SWA3888) at 2025-05-01 05:04:25 with runway 27
# Added landing state for SWA2380 (base SWA2380) at 2025-05-01 05:13:15 with runway 27
# Added landing state for SWA3660 (base SWA3660) at 2025-05-01 05:19:35 with runway 27
# Added landing state for ASA1156 (base ASA1156) at 2025-05-01 05:21:50 with runway 27
# Added landing state for DAL700 (base DAL700) at 2025-05-01 05:24:20 with runway 27
# Added landing state for UAL1835 (base UAL1835) at 2025-05-01 05:26:35 with runway 27
# Added landing state for SKW3746 (base SKW3746) at 2025-05-01 05:28:05 with runway 27
# Added landing state for AAL2578 (base AAL2578) at 2025-05-01 05:30:10 with runway 27
# Added landing state for SWA4150 (base SWA4150) at 2025-05-01 05:31:55 with runway 27
# Added landing state for DAL369 (base DAL369) at 2025-05-01 05:37:05 with runway 27
# Added landing state for SWA3219 (base SWA3219) at 2025-05-01 05:40:10 with runway 27
# Added landing state for SWA4236 (base SWA4236) at 2025-05-01 04:23:00 with runway 27
# Added landing state for ASA297 (base ASA297) at 2025-05-01 04:35:00 with runway 27
# Added landing state for AAL1497 (base AAL1497) at 2025-05-01 04:38:20 with runway 27
# Added landing state for HAL16 (base HAL16) at 2025-05-01 04:50:05 with runway 27
# Added landing state for DAL2672 (base DAL2672) at 2025-05-01 04:52:20 with runway 27
# Added landing state for SWA1515 (base SWA1515) at 2025-05-01 04:55:00 with runway 27
# Added landing state for SWA1328 (base SWA1328) at 2025-05-01 04:57:20 with runway 27
# Added landing state for DAL748 (base DAL748) at 2025-05-01 05:00:20 with runway 27
# Added landing state for UAL1074 (base UAL1074) at 2025-05-01 05:02:15 with runway 27
# Added landing state for SWA3888 (base SWA3888) at 2025-05-01 05:04:25 with runway 27
# Added landing state for SWA2380 (base SWA2380) at 2025-05-01 05:13:15 with runway 27
# Added landing state for SWA3660 (base SWA3660) at 2025-05-01 05:19:35 with runway 27
# Added landing state for ASA1156 (base ASA1156) at 2025-05-01 05:21:50 with runway 27
# Added landing state for DAL700 (base DAL700) at 2025-05-01 05:24:20 with runway 27
# Added landing state for UAL1835 (base UAL1835) at 2025-05-01 05:26:35 with runway 27
# Added landing state for SKW3746 (base SKW3746) at 2025-05-01 05:28:05 with runway 27
# Added landing state for AAL2578 (base AAL2578) at 2025-05-01 05:30:10 with runway 27
# Added landing state for SWA4150 (base SWA4150) at 2025-05-01 05:31:55 with runway 27
# Added landing state for DAL369 (base DAL369) at 2025-05-01 05:37:05 with runway 27
# Added landing state for SWA3219 (base SWA3219) at 2025-05-01 05:40:10 with runway 27
# Added landing state for SWA1170 (base SWA1170) at 2025-05-01 05:43:45 with runway 27
# Added landing state for UAL540 (base UAL540) at 2025-05-01 05:45:05 with runway 27
# Added landing state for UAL2054 (base UAL2054) at 2025-05-01 05:46:45 with runway 27
# Added landing state for SWA103 (base SWA103) at 2025-05-01 06:06:10 with runway 27
# Added landing state for SWA3420 (base SWA3420) at 2025-05-01 06:10:35 with runway 27
# Added landing state for SWA3454 (base SWA3454) at 2025-05-01 06:20:15 with runway 27
# Added landing state for DAL1202 (base DAL1202) at 2025-05-01 06:22:30 with runway 27
# Added landing state for UAL2718 (base UAL2718) at 2025-05-01 06:24:55 with runway 27
# Added landing state for FFT1465 (base FFT1465) at 2025-05-01 06:32:00 with runway 27
# Added landing state for DAL685 (base DAL685) at 2025-05-01 06:34:00 with runway 27
# Added landing state for SKW5612 (base SKW5612) at 2025-05-01 06:36:20 with runway 27
# Added landing state for FFT2711 (base FFT2711) at 2025-05-01 06:41:30 with runway 27
# Added landing state for ASA826 (base ASA826) at 2025-05-01 06:44:10 with runway 27
# Added landing state for AAL1861 (base AAL1861) at 2025-05-01 06:56:25 with runway 27
# Added landing state for KFB236 (base KFB236) at 2025-05-01 07:07:55 with runway 27
# Added landing state for UAL475 (base UAL475) at 2025-05-01 07:17:05 with runway 27
# Added landing state for NKS385 (base NKS385) at 2025-05-01 07:22:25 with runway 27
# Added landing state for FDX1889 (base FDX1889) at 2025-05-01 11:04:00 with runway 27
# Added landing state for UPS922 (base UPS922) at 2025-05-01 11:42:40 with runway 27
# Added landing state for FDX1754 (base FDX1754) at 2025-05-01 11:58:40 with runway 27
# Added landing state for FDX1422 (base FDX1422) at 2025-05-01 13:30:25 with runway 27
# Added landing state for SWA1170 (base SWA1170) at 2025-05-01 05:43:45 with runway 27
# Added landing state for UAL540 (base UAL540) at 2025-05-01 05:45:05 with runway 27
# Added landing state for UAL2054 (base UAL2054) at 2025-05-01 05:46:45 with runway 27
# Added landing state for SWA103 (base SWA103) at 2025-05-01 06:06:10 with runway 27
# Added landing state for SWA3420 (base SWA3420) at 2025-05-01 06:10:35 with runway 27
# Added landing state for SWA3454 (base SWA3454) at 2025-05-01 06:20:15 with runway 27
# Added landing state for DAL1202 (base DAL1202) at 2025-05-01 06:22:30 with runway 27
# Added landing state for UAL2718 (base UAL2718) at 2025-05-01 06:24:55 with runway 27
# Added landing state for FFT1465 (base FFT1465) at 2025-05-01 06:32:00 with runway 27
# Added landing state for DAL685 (base DAL685) at 2025-05-01 06:34:00 with runway 27
# Added landing state for SKW5612 (base SKW5612) at 2025-05-01 06:36:20 with runway 27
# Added landing state for FFT2711 (base FFT2711) at 2025-05-01 06:41:30 with runway 27
# Added landing state for ASA826 (base ASA826) at 2025-05-01 06:44:10 with runway 27
# Added landing state for AAL1861 (base AAL1861) at 2025-05-01 06:56:25 with runway 27
# Added landing state for KFB236 (base KFB236) at 2025-05-01 07:07:55 with runway 27
# Added landing state for UAL475 (base UAL475) at 2025-05-01 07:17:05 with runway 27
# Added landing state for NKS385 (base NKS385) at 2025-05-01 07:22:25 with runway 27
# Added landing state for FDX1889 (base FDX1889) at 2025-05-01 11:04:00 with runway 27
# Added landing state for SWA2512 (base SWA2512) at 2025-05-01 15:59:30 with runway 27
# Added landing state for SKW3967 (base SKW3967) at 2025-05-01 16:04:05 with runway 27
# Added landing state for RGY872 (base RGY872) at 2025-05-01 16:06:00 with runway 27
# Added landing state for SWA1261 (base SWA1261) at 2025-05-01 16:08:30 with runway 27
# Added landing state for N636SY (base N636SY) at 2025-05-01 16:11:50 with runway 27
# Added landing state for UAL2309 (base UAL2309) at 2025-05-01 16:13:55 with runway 27
# Added landing state for ASA1074 (base ASA1074) at 2025-05-01 16:15:35 with runway 27
# Added landing state for SWA1201 (base SWA1201) at 2025-05-01 16:18:00 with runway 27
# Added landing state for SKW3105 (base SKW3105) at 2025-05-01 16:20:40 with runway 27
# Added landing state for SKW4643 (base SKW4643) at 2025-05-01 16:22:45 with runway 27
# Added landing state for HRT223 (base HRT223) at 2025-05-01 16:24:50 with runway 27
# Added landing state for SWA1432 (base SWA1432) at 2025-05-01 16:26:20 with runway 27
# Added landing state for FFT2817 (base FFT2817) at 2025-05-01 16:28:40 with runway 27
# Added landing state for QXE2154 (base QXE2154) at 2025-05-01 16:31:10 with runway 27
# Added landing state for ASA1258 (base ASA1258) at 2025-05-01 16:34:00 with runway 27
# Added landing state for DAL2508 (base DAL2508) at 2025-05-01 16:36:50 with runway 27
# Added landing state for UAL1483 (base UAL1483) at 2025-05-01 16:40:00 with runway 27
# Added landing state for SWA2134 (base SWA2134) at 2025-05-01 16:41:50 with runway 27
# Added landing state for TIV799 (base TIV799) at 2025-05-01 16:44:15 with runway 27
# Added landing state for CGNRC (base CGNRC) at 2025-05-01 16:48:25 with runway 27
# Added landing state for DAL725 (base DAL725) at 2025-05-01 16:50:55 with runway 27
# Added landing state for AAL2050 (base AAL2050) at 2025-05-01 16:53:00 with runway 27
# Added landing state for ASA912 (base ASA912) at 2025-05-01 16:55:35 with runway 27
# Added landing state for CSB529 (base CSB529) at 2025-05-01 16:57:30 with runway 27
# Added landing state for SWA1364 (base SWA1364) at 2025-05-01 16:59:55 with runway 27
# Added landing state for NKS379_1 (base NKS379) at 2025-05-01 17:01:45 with runway 27
# Added landing state for JCM718 (base JCM718) at 2025-05-01 17:06:25 with runway 27
# Added landing state for SKW3456 (base SKW3456) at 2025-05-01 17:08:25 with runway 27
# Added landing state for SKW4018 (base SKW4018) at 2025-05-01 17:11:10 with runway 27
# Added landing state for SWA2014 (base SWA2014) at 2025-05-01 17:13:40 with runway 27
# Added landing state for TSU7122 (base TSU7122) at 2025-05-01 17:14:55 with runway 27
# Added landing state for LXJ468 (base LXJ468) at 2025-05-01 17:17:00 with runway 27
# Added landing state for SWA9005 (base SWA9005) at 2025-05-01 17:20:25 with runway 27
# Added landing state for SWA2283 (base SWA2283) at 2025-05-01 17:23:10 with runway 27
# Added landing state for AAL1093 (base AAL1093) at 2025-05-01 17:25:50 with runway 27
# Added landing state for DAL2121 (base DAL2121) at 2025-05-01 17:31:45 with runway 27
# Added landing state for AAL2275 (base AAL2275) at 2025-05-01 17:33:40 with runway 27
# Added landing state for DAL492 (base DAL492) at 2025-05-01 17:35:20 with runway 27
# Added landing state for TIV70 (base TIV70) at 2025-05-01 17:37:35 with runway 27
# Added landing state for SWA1219 (base SWA1219) at 2025-05-01 17:41:10 with runway 27
# Added landing state for CGNRC (base CGNRC) at 2025-05-01 16:48:25 with runway 27
# Added landing state for DAL725 (base DAL725) at 2025-05-01 16:50:55 with runway 27
# Added landing state for AAL2050 (base AAL2050) at 2025-05-01 16:53:00 with runway 27
# Added landing state for ASA912 (base ASA912) at 2025-05-01 16:55:35 with runway 27
# Added landing state for CSB529 (base CSB529) at 2025-05-01 16:57:30 with runway 27
# Added landing state for SWA1364 (base SWA1364) at 2025-05-01 16:59:55 with runway 27
# Added landing state for NKS379_1 (base NKS379) at 2025-05-01 17:01:45 with runway 27
# Added landing state for JCM718 (base JCM718) at 2025-05-01 17:06:25 with runway 27
# Added landing state for SKW3456 (base SKW3456) at 2025-05-01 17:08:25 with runway 27
# Added landing state for SKW4018 (base SKW4018) at 2025-05-01 17:11:10 with runway 27
# Added landing state for SWA2014 (base SWA2014) at 2025-05-01 17:13:40 with runway 27
# Added landing state for TSU7122 (base TSU7122) at 2025-05-01 17:14:55 with runway 27
# Added landing state for LXJ468 (base LXJ468) at 2025-05-01 17:17:00 with runway 27
# Added landing state for SWA9005 (base SWA9005) at 2025-05-01 17:20:25 with runway 27
# Added landing state for SWA2283 (base SWA2283) at 2025-05-01 17:23:10 with runway 27
# Added landing state for AAL1093 (base AAL1093) at 2025-05-01 17:25:50 with runway 27
# Added landing state for DAL2121 (base DAL2121) at 2025-05-01 17:31:45 with runway 27
# Added landing state for AAL2275 (base AAL2275) at 2025-05-01 17:33:40 with runway 27
# Added landing state for DAL492 (base DAL492) at 2025-05-01 17:35:20 with runway 27
# Added landing state for TIV70 (base TIV70) at 2025-05-01 17:37:35 with runway 27
# Added landing state for SWA1219 (base SWA1219) at 2025-05-01 17:41:10 with runway 27
# Added landing state for FFT1425 (base FFT1425) at 2025-05-01 17:43:00 with runway 27
# Added landing state for UAL8191 (base UAL8191) at 2025-05-01 17:45:50 with runway 27
# Added landing state for ASA433 (base ASA433) at 2025-05-01 17:59:00 with runway 27
# Added landing state for JAL66 (base JAL66) at 2025-05-01 18:01:10 with runway 27
# Added landing state for JBU619 (base JBU619) at 2025-05-01 18:02:55 with runway 27
# Added landing state for UAL1930 (base UAL1930) at 2025-05-01 18:04:40 with runway 27
# Added landing state for SWA673_1 (base SWA673) at 2025-05-01 18:06:40 with runway 27
# Added landing state for SWA2196 (base SWA2196) at 2025-05-01 18:08:30 with runway 27
# Added landing state for UAL1826 (base UAL1826) at 2025-05-01 18:10:00 with runway 27
# Added landing state for N40JD (base N40JD) at 2025-05-01 18:12:05 with runway 27
# Added landing state for SWA5830 (base SWA5830) at 2025-05-01 18:14:35 with runway 27
# Added landing state for SWA1762 (base SWA1762) at 2025-05-01 18:15:55 with runway 27
# Added landing state for SWA2409 (base SWA2409) at 2025-05-01 18:17:15 with runway 27
# Added landing state for SWA2932 (base SWA2932) at 2025-05-01 18:19:40 with runway 27
# Added landing state for UAL660 (base UAL660) at 2025-05-01 18:21:15 with runway 27
# Added landing state for SWA102 (base SWA102) at 2025-05-01 18:22:50 with runway 27
# Added landing state for N150LR (base N150LR) at 2025-05-01 18:24:35 with runway 27
# Added landing state for SWA2592 (base SWA2592) at 2025-05-01 18:27:40 with runway 27
# Added landing state for MXY542 (base MXY542) at 2025-05-01 18:30:10 with runway 27
# Added landing state for ACA1093 (base ACA1093) at 2025-05-01 18:32:50 with runway 27
# Added landing state for LXJ366 (base LXJ366) at 2025-05-01 18:36:20 with runway 27
# Added landing state for FFT1425 (base FFT1425) at 2025-05-01 17:43:00 with runway 27
# Added landing state for UAL8191 (base UAL8191) at 2025-05-01 17:45:50 with runway 27
# Added landing state for ASA433 (base ASA433) at 2025-05-01 17:59:00 with runway 27
# Added landing state for JAL66 (base JAL66) at 2025-05-01 18:01:10 with runway 27
# Added landing state for JBU619 (base JBU619) at 2025-05-01 18:02:55 with runway 27
# Added landing state for UAL1930 (base UAL1930) at 2025-05-01 18:04:40 with runway 27
# Added landing state for SWA673_1 (base SWA673) at 2025-05-01 18:06:40 with runway 27
# Added landing state for SWA2196 (base SWA2196) at 2025-05-01 18:08:30 with runway 27
# Added landing state for UAL1826 (base UAL1826) at 2025-05-01 18:10:00 with runway 27
# Added landing state for N40JD (base N40JD) at 2025-05-01 18:12:05 with runway 27
# Added landing state for SWA5830 (base SWA5830) at 2025-05-01 18:14:35 with runway 27
# Added landing state for SWA1762 (base SWA1762) at 2025-05-01 18:15:55 with runway 27
# Added landing state for SWA2409 (base SWA2409) at 2025-05-01 18:17:15 with runway 27
# Added landing state for SWA2932 (base SWA2932) at 2025-05-01 18:19:40 with runway 27
# Added landing state for UAL660 (base UAL660) at 2025-05-01 18:21:15 with runway 27
# Added landing state for SWA102 (base SWA102) at 2025-05-01 18:22:50 with runway 27
# Added landing state for N150LR (base N150LR) at 2025-05-01 18:24:35 with runway 27
# Added landing state for SWA2592 (base SWA2592) at 2025-05-01 18:27:40 with runway 27
# Added landing state for MXY542 (base MXY542) at 2025-05-01 18:30:10 with runway 27
# Added landing state for ACA1093 (base ACA1093) at 2025-05-01 18:32:50 with runway 27
# Added landing state for LXJ366 (base LXJ366) at 2025-05-01 18:36:20 with runway 27
# Added landing state for ASA884 (base ASA884) at 2025-05-01 18:38:30 with runway 27
# Added landing state for AAL1621 (base AAL1621) at 2025-05-01 18:40:00 with runway 27
# Added landing state for JZA764 (base JZA764) at 2025-05-01 18:41:55 with runway 27
# Added landing state for LXJ605 (base LXJ605) at 2025-05-01 18:43:35 with runway 27
# Added landing state for SKW3498 (base SKW3498) at 2025-05-01 18:45:10 with runway 27
# Added landing state for N34SJ (base N34SJ) at 2025-05-01 18:49:15 with runway 27
# Added landing state for N651WE (base N651WE) at 2025-05-01 18:50:50 with runway 27
# Added landing state for JBU919 (base JBU919) at 2025-05-01 18:51:50 with runway 27
# Added landing state for SKW3200 (base SKW3200) at 2025-05-01 18:53:40 with runway 27
# Added landing state for SKW3165 (base SKW3165) at 2025-05-01 18:59:40 with runway 27
# Added landing state for SKW3342_1 (base SKW3342) at 2025-05-01 19:01:15 with runway 27
# Added landing state for SKW3373 (base SKW3373) at 2025-05-01 19:03:20 with runway 27
# Added landing state for SWA1062 (base SWA1062) at 2025-05-01 19:05:10 with runway 27
# Added landing state for DAL1179 (base DAL1179) at 2025-05-01 19:08:30 with runway 27
# Added landing state for DAL2533 (base DAL2533) at 2025-05-01 19:10:50 with runway 27
# Added landing state for SWA2584 (base SWA2584) at 2025-05-01 19:12:55 with runway 27
# Added landing state for EJM557 (base EJM557) at 2025-05-01 19:15:05 with runway 27
# Added landing state for N29HG (base N29HG) at 2025-05-01 19:16:45 with runway 27
# Added landing state for ASA27 (base ASA27) at 2025-05-01 19:18:30 with runway 27
# Added landing state for ASA884 (base ASA884) at 2025-05-01 18:38:30 with runway 27
# Added landing state for AAL1621 (base AAL1621) at 2025-05-01 18:40:00 with runway 27
# Added landing state for JZA764 (base JZA764) at 2025-05-01 18:41:55 with runway 27
# Added landing state for LXJ605 (base LXJ605) at 2025-05-01 18:43:35 with runway 27
# Added landing state for SKW3498 (base SKW3498) at 2025-05-01 18:45:10 with runway 27
# Added landing state for N34SJ (base N34SJ) at 2025-05-01 18:49:15 with runway 27
# Added landing state for N651WE (base N651WE) at 2025-05-01 18:50:50 with runway 27
# Added landing state for JBU919 (base JBU919) at 2025-05-01 18:51:50 with runway 27
# Added landing state for SKW3200 (base SKW3200) at 2025-05-01 18:53:40 with runway 27
# Added landing state for SKW3165 (base SKW3165) at 2025-05-01 18:59:40 with runway 27
# Added landing state for SKW3342_1 (base SKW3342) at 2025-05-01 19:01:15 with runway 27
# Added landing state for SKW3373 (base SKW3373) at 2025-05-01 19:03:20 with runway 27
# Added landing state for SWA1062 (base SWA1062) at 2025-05-01 19:05:10 with runway 27
# Added landing state for DAL1179 (base DAL1179) at 2025-05-01 19:08:30 with runway 27
# Added landing state for DAL2533 (base DAL2533) at 2025-05-01 19:10:50 with runway 27
# Added landing state for SWA2584 (base SWA2584) at 2025-05-01 19:12:55 with runway 27
# Added landing state for EJM557 (base EJM557) at 2025-05-01 19:15:05 with runway 27
# Added landing state for N29HG (base N29HG) at 2025-05-01 19:16:45 with runway 27
# Added landing state for ASA27 (base ASA27) at 2025-05-01 19:18:30 with runway 27
# Added landing state for UAL1179 (base UAL1179) at 2025-05-01 19:20:55 with runway 27
# Added landing state for AAL2122 (base AAL2122) at 2025-05-01 19:22:55 with runway 27
# Added landing state for N90KC (base N90KC) at 2025-05-01 19:24:50 with runway 27
# Added landing state for MXY754 (base MXY754) at 2025-05-01 19:28:15 with runway 27
# Added landing state for N430E (base N430E) at 2025-05-01 19:31:05 with runway 27
# Added landing state for AAL2784 (base AAL2784) at 2025-05-01 19:35:30 with runway 27
# Added landing state for UAL2381 (base UAL2381) at 2025-05-01 19:39:00 with runway 27
# Added landing state for SWA269 (base SWA269) at 2025-05-01 19:39:50 with runway 27
# Added landing state for DAL683 (base DAL683) at 2025-05-01 19:41:45 with runway 27
# Added landing state for DAL2125 (base DAL2125) at 2025-05-01 19:44:45 with runway 27
# Added landing state for ASA1296 (base ASA1296) at 2025-05-01 19:48:05 with runway 27
# Added landing state for WJA1564 (base WJA1564) at 2025-05-01 19:52:20 with runway 27
# Added landing state for DAL894 (base DAL894) at 2025-05-01 19:54:00 with runway 27
# Added landing state for SWA1974 (base SWA1974) at 2025-05-01 19:59:00 with runway 27
# Added landing state for ASA1108 (base ASA1108) at 2025-05-01 20:02:20 with runway 27
# Added landing state for SKW3785 (base SKW3785) at 2025-05-01 20:04:35 with runway 27
# Added landing state for UAL2294 (base UAL2294) at 2025-05-01 20:16:05 with runway 27
# Added landing state for SWA1014 (base SWA1014) at 2025-05-01 20:18:30 with runway 27
# Added landing state for ASA15 (base ASA15) at 2025-05-01 20:26:10 with runway 27
# Added landing state for SKW3141 (base SKW3141) at 2025-05-01 20:29:25 with runway 27
# Added landing state for UAL2693 (base UAL2693) at 2025-05-01 20:31:05 with runway 27
# Added landing state for UAL1179 (base UAL1179) at 2025-05-01 19:20:55 with runway 27
# Added landing state for AAL2122 (base AAL2122) at 2025-05-01 19:22:55 with runway 27
# Added landing state for N90KC (base N90KC) at 2025-05-01 19:24:50 with runway 27
# Added landing state for MXY754 (base MXY754) at 2025-05-01 19:28:15 with runway 27
# Added landing state for N430E (base N430E) at 2025-05-01 19:31:05 with runway 27
# Added landing state for AAL2784 (base AAL2784) at 2025-05-01 19:35:30 with runway 27
# Added landing state for UAL2381 (base UAL2381) at 2025-05-01 19:39:00 with runway 27
# Added landing state for SWA269 (base SWA269) at 2025-05-01 19:39:50 with runway 27
# Added landing state for DAL683 (base DAL683) at 2025-05-01 19:41:45 with runway 27
# Added landing state for DAL2125 (base DAL2125) at 2025-05-01 19:44:45 with runway 27
# Added landing state for ASA1296 (base ASA1296) at 2025-05-01 19:48:05 with runway 27
# Added landing state for WJA1564 (base WJA1564) at 2025-05-01 19:52:20 with runway 27
# Added landing state for DAL894 (base DAL894) at 2025-05-01 19:54:00 with runway 27
# Added landing state for SWA1974 (base SWA1974) at 2025-05-01 19:59:00 with runway 27
# Added landing state for ASA1108 (base ASA1108) at 2025-05-01 20:02:20 with runway 27
# Added landing state for SKW3785 (base SKW3785) at 2025-05-01 20:04:35 with runway 27
# Added landing state for UAL2294 (base UAL2294) at 2025-05-01 20:16:05 with runway 27
# Added landing state for SWA1014 (base SWA1014) at 2025-05-01 20:18:30 with runway 27
# Added landing state for ASA15 (base ASA15) at 2025-05-01 20:26:10 with runway 27
# Added landing state for SKW3141 (base SKW3141) at 2025-05-01 20:29:25 with runway 27
# Added landing state for UAL2693 (base UAL2693) at 2025-05-01 20:31:05 with runway 27
# Added landing state for SWA4525 (base SWA4525) at 2025-05-01 20:33:20 with runway 27
# Added landing state for SWA2118 (base SWA2118) at 2025-05-01 20:39:05 with runway 27
# Added landing state for SWA1155 (base SWA1155) at 2025-05-01 20:41:40 with runway 27
# Added landing state for DAL2172 (base DAL2172) at 2025-05-01 20:43:25 with runway 27
# Added landing state for AAL466 (base AAL466) at 2025-05-01 20:45:50 with runway 27
# Added landing state for UAL2739 (base UAL2739) at 2025-05-01 20:47:30 with runway 27
# Added landing state for N582MM (base N582MM) at 2025-05-01 20:50:25 with runway 27
# Added landing state for N857QS (base N857QS) at 2025-05-01 20:53:30 with runway 27
# Added landing state for N370QS (base N370QS) at 2025-05-01 20:58:20 with runway 27
# Added landing state for EJA784 (base EJA784) at 2025-05-01 20:59:55 with runway 27
# Added landing state for SKW3421 (base SKW3421) at 2025-05-01 21:01:45 with runway 27
# Added landing state for SWA1065 (base SWA1065) at 2025-05-01 21:04:50 with runway 27
# Added landing state for N96PB_2 (base N96PB) at 2025-05-01 21:10:10 with runway 27
# Added landing state for SWA1681 (base SWA1681) at 2025-05-01 21:12:35 with runway 27
# Added landing state for SWA3677 (base SWA3677) at 2025-05-01 21:14:50 with runway 27
# Added landing state for SWA1356_1 (base SWA1356) at 2025-05-01 21:17:10 with runway 27
# Added landing state for AAL1939 (base AAL1939) at 2025-05-01 21:19:15 with runway 27
# Added landing state for SWA3627 (base SWA3627) at 2025-05-01 21:22:00 with runway 27
# Added landing state for BAW265 (base BAW265) at 2025-05-01 21:25:35 with runway 27
# Added landing state for QXE2031 (base QXE2031) at 2025-05-01 21:28:10 with runway 27
# Added landing state for SWA4525 (base SWA4525) at 2025-05-01 20:33:20 with runway 27
# Added landing state for SWA2118 (base SWA2118) at 2025-05-01 20:39:05 with runway 27
# Added landing state for SWA1155 (base SWA1155) at 2025-05-01 20:41:40 with runway 27
# Added landing state for DAL2172 (base DAL2172) at 2025-05-01 20:43:25 with runway 27
# Added landing state for AAL466 (base AAL466) at 2025-05-01 20:45:50 with runway 27
# Added landing state for UAL2739 (base UAL2739) at 2025-05-01 20:47:30 with runway 27
# Added landing state for N582MM (base N582MM) at 2025-05-01 20:50:25 with runway 27
# Added landing state for N857QS (base N857QS) at 2025-05-01 20:53:30 with runway 27
# Added landing state for N370QS (base N370QS) at 2025-05-01 20:58:20 with runway 27
# Added landing state for EJA784 (base EJA784) at 2025-05-01 20:59:55 with runway 27
# Added landing state for SKW3421 (base SKW3421) at 2025-05-01 21:01:45 with runway 27
# Added landing state for SWA1065 (base SWA1065) at 2025-05-01 21:04:50 with runway 27
# Added landing state for N96PB_2 (base N96PB) at 2025-05-01 21:10:10 with runway 27
# Added landing state for SWA1681 (base SWA1681) at 2025-05-01 21:12:35 with runway 27
# Added landing state for SWA3677 (base SWA3677) at 2025-05-01 21:14:50 with runway 27
# Added landing state for SWA1356_1 (base SWA1356) at 2025-05-01 21:17:10 with runway 27
# Added landing state for AAL1939 (base AAL1939) at 2025-05-01 21:19:15 with runway 27
# Added landing state for SWA3627 (base SWA3627) at 2025-05-01 21:22:00 with runway 27
# Added landing state for BAW265 (base BAW265) at 2025-05-01 21:25:35 with runway 27
# Added landing state for QXE2031 (base QXE2031) at 2025-05-01 21:28:10 with runway 27
# Added landing state for ASA1395 (base ASA1395) at 2025-05-01 21:29:30 with runway 27
# Added landing state for DAL2572 (base DAL2572) at 2025-05-01 21:31:10 with runway 27
# Added landing state for UAL1302 (base UAL1302) at 2025-05-01 21:33:00 with runway 27
# Added landing state for UAL2391 (base UAL2391) at 2025-05-01 21:36:10 with runway 27
# Added landing state for WCC55 (base WCC55) at 2025-05-01 21:40:55 with runway 27
# Added landing state for SWA952 (base SWA952) at 2025-05-01 21:43:30 with runway 27
# Added landing state for ASA1096 (base ASA1096) at 2025-05-01 21:46:35 with runway 27
# Added landing state for CNS814 (base CNS814) at 2025-05-01 21:49:35 with runway 27
# Added landing state for SWA2547_1 (base SWA2547) at 2025-05-01 21:51:45 with runway None
# Added landing state for NKS381 (base NKS381) at 2025-05-01 21:56:55 with runway 27
# Added landing state for SWA3208 (base SWA3208) at 2025-05-01 22:04:15 with runway 27
# Added landing state for XAPSO (base XAPSO) at 2025-05-01 22:07:00 with runway None
# Added landing state for DLH5Y (base DLH5Y) at 2025-05-01 22:09:00 with runway 27
# Added landing state for EJA751 (base EJA751) at 2025-05-01 22:11:45 with runway 27
# Added landing state for SWA2316_1 (base SWA2316) at 2025-05-01 22:17:35 with runway 27
# Added landing state for UAL2029 (base UAL2029) at 2025-05-01 22:18:55 with runway 27
# Added landing state for VJA549 (base VJA549) at 2025-05-01 22:21:00 with runway 27
# Added landing state for AAL1951_1 (base AAL1951) at 2025-05-01 22:22:10 with runway 27
# Added landing state for LET3269 (base LET3269) at 2025-05-01 22:24:05 with runway 27
# Added landing state for SKW3320_1 (base SKW3320) at 2025-05-01 22:26:05 with runway 27
# Added landing state for SKW3383_1 (base SKW3383) at 2025-05-01 22:30:00 with runway 27
# Added landing state for ASA1395 (base ASA1395) at 2025-05-01 21:29:30 with runway 27
# Added landing state for DAL2572 (base DAL2572) at 2025-05-01 21:31:10 with runway 27
# Added landing state for UAL1302 (base UAL1302) at 2025-05-01 21:33:00 with runway 27
# Added landing state for UAL2391 (base UAL2391) at 2025-05-01 21:36:10 with runway 27
# Added landing state for WCC55 (base WCC55) at 2025-05-01 21:40:55 with runway 27
# Added landing state for SWA952 (base SWA952) at 2025-05-01 21:43:30 with runway 27
# Added landing state for ASA1096 (base ASA1096) at 2025-05-01 21:46:35 with runway 27
# Added landing state for CNS814 (base CNS814) at 2025-05-01 21:49:35 with runway 27
# Added landing state for SWA2547_1 (base SWA2547) at 2025-05-01 21:51:45 with runway None
# Added landing state for NKS381 (base NKS381) at 2025-05-01 21:56:55 with runway 27
# Added landing state for SWA3208 (base SWA3208) at 2025-05-01 22:04:15 with runway 27
# Added landing state for XAPSO (base XAPSO) at 2025-05-01 22:07:00 with runway None
# Added landing state for DLH5Y (base DLH5Y) at 2025-05-01 22:09:00 with runway 27
# Added landing state for EJA751 (base EJA751) at 2025-05-01 22:11:45 with runway 27
# Added landing state for SWA2316_1 (base SWA2316) at 2025-05-01 22:17:35 with runway 27
# Added landing state for UAL2029 (base UAL2029) at 2025-05-01 22:18:55 with runway 27
# Added landing state for VJA549 (base VJA549) at 2025-05-01 22:21:00 with runway 27
# Added landing state for AAL1951_1 (base AAL1951) at 2025-05-01 22:22:10 with runway 27
# Added landing state for LET3269 (base LET3269) at 2025-05-01 22:24:05 with runway 27
# Added landing state for SKW3320_1 (base SKW3320) at 2025-05-01 22:26:05 with runway 27
# Added landing state for SKW3383_1 (base SKW3383) at 2025-05-01 22:30:00 with runway 27
# Added landing state for SWA1305 (base SWA1305) at 2025-05-01 22:38:25 with runway 27
# Added landing state for SWA2599 (base SWA2599) at 2025-05-01 22:46:35 with runway 27
# Added landing state for SWA3425 (base SWA3425) at 2025-05-01 22:50:00 with runway 27
# Added landing state for EJA613 (base EJA613) at 2025-05-01 22:51:50 with runway 27
# Added landing state for XATFR (base XATFR) at 2025-05-01 22:57:45 with runway 27
# Added landing state for DAL843 (base DAL843) at 2025-05-01 23:04:10 with runway 27
# Added landing state for SWA2281 (base SWA2281) at 2025-05-01 23:07:00 with runway 27
# Added landing state for N149WW (base N149WW) at 2025-05-01 23:08:35 with runway 27
# Added landing state for AAL2361_1 (base AAL2361) at 2025-05-01 23:10:20 with runway 27
# Added landing state for FLC76_1 (base FLC76) at 2025-05-01 23:12:25 with runway 27
# Added landing state for JZA766 (base JZA766) at 2025-05-01 23:14:35 with runway 27
# Added landing state for ASA1198 (base ASA1198) at 2025-05-01 23:17:45 with runway 27
# Added landing state for SKW3496 (base SKW3496) at 2025-05-01 23:19:50 with runway 27
# Added landing state for SKW3185 (base SKW3185) at 2025-05-01 23:22:20 with runway 27
# Added landing state for SKW3346_1 (base SKW3346) at 2025-05-01 23:24:10 with runway 27
# Added landing state for SWA3760 (base SWA3760) at 2025-05-01 23:25:45 with runway 27
# Added landing state for SCX407 (base SCX407) at 2025-05-01 23:32:05 with runway 27
# Added landing state for DAL1210_1 (base DAL1210) at 2025-05-01 23:33:55 with runway 27
# Added landing state for SWA2853_1 (base SWA2853) at 2025-05-01 23:36:05 with runway 27
# Added landing state for SWA2022 (base SWA2022) at 2025-05-01 23:40:10 with runway 27
# Added landing state for SWA921_1 (base SWA921) at 2025-05-01 23:41:30 with runway 27
# Added landing state for SWA1305 (base SWA1305) at 2025-05-01 22:38:25 with runway 27
# Added landing state for SWA2599 (base SWA2599) at 2025-05-01 22:46:35 with runway 27
# Added landing state for SWA3425 (base SWA3425) at 2025-05-01 22:50:00 with runway 27
# Added landing state for EJA613 (base EJA613) at 2025-05-01 22:51:50 with runway 27
# Added landing state for XATFR (base XATFR) at 2025-05-01 22:57:45 with runway 27
# Added landing state for DAL843 (base DAL843) at 2025-05-01 23:04:10 with runway 27
# Added landing state for SWA2281 (base SWA2281) at 2025-05-01 23:07:00 with runway 27
# Added landing state for N149WW (base N149WW) at 2025-05-01 23:08:35 with runway 27
# Added landing state for AAL2361_1 (base AAL2361) at 2025-05-01 23:10:20 with runway 27
# Added landing state for FLC76_1 (base FLC76) at 2025-05-01 23:12:25 with runway 27
# Added landing state for JZA766 (base JZA766) at 2025-05-01 23:14:35 with runway 27
# Added landing state for ASA1198 (base ASA1198) at 2025-05-01 23:17:45 with runway 27
# Added landing state for SKW3496 (base SKW3496) at 2025-05-01 23:19:50 with runway 27
# Added landing state for SKW3185 (base SKW3185) at 2025-05-01 23:22:20 with runway 27
# Added landing state for SKW3346_1 (base SKW3346) at 2025-05-01 23:24:10 with runway 27
# Added landing state for SWA3760 (base SWA3760) at 2025-05-01 23:25:45 with runway 27
# Added landing state for SCX407 (base SCX407) at 2025-05-01 23:32:05 with runway 27
# Added landing state for DAL1210_1 (base DAL1210) at 2025-05-01 23:33:55 with runway 27
# Added landing state for SWA2853_1 (base SWA2853) at 2025-05-01 23:36:05 with runway 27
# Added landing state for SWA2022 (base SWA2022) at 2025-05-01 23:40:10 with runway 27
# Added landing state for SWA921_1 (base SWA921) at 2025-05-01 23:41:30 with runway 27
# Added landing state for SKW4087 (base SKW4087) at 2025-05-01 23:43:15 with runway 27
# Added landing state for ASA1204 (base ASA1204) at 2025-05-01 23:50:15 with runway 27
# Added landing state for UAL2683 (base UAL2683) at 2025-05-01 23:52:05 with runway 27
# Added landing state for UAL1416 (base UAL1416) at 2025-05-01 23:53:55 with runway 27
# {'callsign': 'UAL1416', 'lat': 32.686188, 'lon': -116.994866, 'alt': 1130.1984, 'v_z': 0.0, 'gspd': 101.50012346695202, 'hdg': 286.0, 'model': 'B739', 'state': 'landing', 'time_added': 86035, 'runway': 27}
# Added landing state for SKW4087 (base SKW4087) at 2025-05-01 23:43:15 with runway 27
# Added landing state for ASA1204 (base ASA1204) at 2025-05-01 23:50:15 with runway 27
# Added landing state for UAL2683 (base UAL2683) at 2025-05-01 23:52:05 with runway 27
# Added landing state for UAL1416 (base UAL1416) at 2025-05-01 23:53:55 with runway 27
# {'callsign': 'UAL1416', 'lat': 32.686188, 'lon': -116.994866, 'alt': 1130.1984, 'v_z': 0.0, 'gspd': 101.50012346695202, 'hdg': 286.0, 'model': 'B739', 'state': 'landing', 'time_added': 86035, 'runway': 27}

# %%
# sort by time_added
rolling_initial_state.sort(key=lambda x: x['time_added'])

# %%
# round altitudes down below 3000 feet
for state in rolling_initial_state:
    if state['alt'] is not None and state['alt'] > 914.4:  # 3000 feet in meters
        state['alt'] = 914.4

# %%
# if runway is not 27, drop the state
rolling_initial_state = [state for state in rolling_initial_state if state['runway'] == 27]

# %%
import copy

def create_rolling_initial_states(original_states, window_size=10):
    rolling_states = []
    
    for i in range(len(original_states) - window_size + 1):
        # Create a deep copy of the window
        window = copy.deepcopy(original_states[i:i+window_size])
        
        # Get the time_added of the first aircraft in this window
        first_time = window[0]['time_added']
        
        # Adjust time_added for all aircraft relative to the first one
        for aircraft in window:
            aircraft['time_added'] = aircraft['time_added'] - first_time
            
        rolling_states.append(window)
    
    return rolling_states

# Use the new function to create rolling initial state chunks
chunks = create_rolling_initial_states(rolling_initial_state, window_size=10)

# %%
# remove noisy chunks that have abnormal time added values
chunks = [chunk for chunk in chunks if all(aircraft['time_added'] <= 1800 for aircraft in chunk)]

# %%
# export the rolling initial state dictionary to a python file
with open("../rolling_initial_state_20250501.py", "w") as f:
    for i in range(len(chunks)):
        rolling_initial_state = chunks[i]
        f.write(f"rolling_initial_state_{i:02d} = {rolling_initial_state}\n")
